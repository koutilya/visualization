# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import codecs
import time
import re

# %%
# headers = {
#     'User-Agent': 'Your Name, example.com',
#     'From': 'email@example.com'
# }

# %%
s_d = "kRewragAminA varwmanA AgacCawi yAwrikaM apaSyaw"
s_c = s_d.replace(" ","+")
urlname = ("http://sanskrit.inria.fr/cgi-bin/SKT/sktgraph?lex=SH&st=t&us=f&cp=t&text=" +
           s_c + "&t=WX&topic=&mode=g&corpmode=&corpdir=&sentno=")

print(urlname)
page = requests.get(urlname)
# Out:
# http://sanskrit.inria.fr/cgi-bin/SKT/sktgraph?lex=SH&st=t&us=f&cp=t&text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw&t=WX&topic=&mode=g&corpmode=&corpdir=&sentno=

# %%
soup = bs(page.text, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Sanskrit Segmenter Summary\n  </title>\n  <meta content="Gérard Huet" name="author"/>\n  <meta content="2017" property="dc:datecopyrighted"/>\n  <meta content="Gérard Huet" property="dc:rightsholder"/>\n  <meta content="dictionary,sanskrit,heritage,dictionnaire,sanscrit,india,inde,indology,linguistics,panini,digital humanities,cultural heritage,computational linguistics,hypertext lexicon" name="keywords"/>\n  <link href="http://sanskrit.inria.fr/DICO/style.css" media="screen,tv" rel="stylesheet" type="text/css"/>\n  <link href="http://sanskrit.inria.fr/IMAGES/favicon.ico" rel="shortcut icon"/>\n  <script src="http://sanskrit.inria.fr/DICO/utf82VH.js" type="text/javascript">\n  </script>\n  <script src="http://sanskrit.inria.fr/DICO/util.js" type="text/javascript">\n  </script>\n </head>\n <body class="chamois_back">\n  <h1 class="title">\n   Sanskrit Segmenter Summary\n  </h1>\n  <h3 class="c3">\n   Click on\n   <span class="green">\n    ✓\n   </span>\n   to select segment, click on\n   <span class="red">\n    ✘\n   </span>\n   to rule out segment\n  </h3>\n  <h3 class="c3">\n   Click on segment to get its lemma\n  </h3>\n  <table border="0" cellpadding="0%" cellspacing="15pt" class="chamois_back" width="100%">\n   <tr>\n    <td>\n     <br/>\n     <span class="latin16">\n      Sentence:\n     </span>\n     <span class="deva16" lang="sa">\n      क्षेत्रगामिना वर्त्मना आगच्छति यात्रिकम् अपश्यत्\n     </span>\n     <br/>\n     <div class="latin16">\n      <table class="spacing20">\n       <tr>\n        <td>\n         <a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=">\n          ✓\n         </a>\n         Undo\n        </td>\n        <td>\n         (300 Solutions)\n        </td>\n       </tr>\n      </table>\n     </div>\n     <br/>\n     <div class="latin12">\n      <table class="center">\n       <tr>\n        <td>\n         k\n        </td>\n        <td>\n         ṣ\n        </td>\n        <td>\n         e\n        </td>\n        <td>\n         t\n        </td>\n        <td>\n         r\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         g\n        </td>\n        <td>\n         ā\n        </td>\n        <td>\n         m\n        </td>\n        <td>\n         i\n        </td>\n        <td>\n         n\n        </td>\n        <td>\n         ā\n        </td>\n        <td>\n         _\n        </td>\n        <td>\n         v\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         r\n        </td>\n        <td>\n         t\n        </td>\n        <td>\n         m\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         n\n        </td>\n        <td>\n         ā\n        </td>\n        <td>\n         _\n        </td>\n        <td>\n         ā\n        </td>\n        <td>\n         g\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         c\n        </td>\n        <td>\n         ch\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         t\n        </td>\n        <td>\n         i\n        </td>\n        <td>\n        </td>\n        <td>\n         y\n        </td>\n        <td>\n         ā\n        </td>\n        <td>\n         t\n        </td>\n        <td>\n         r\n        </td>\n        <td>\n         i\n        </td>\n        <td>\n         k\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         m\n        </td>\n        <td>\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         p\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         ś\n        </td>\n        <td>\n         y\n        </td>\n        <td>\n         a\n        </td>\n        <td>\n         t\n        </td>\n        <td>\n        </td>\n       </tr>\n      ...

# %%
table = soup.table
print(table)
# Out:
# <table border="0" cellpadding="0%" cellspacing="15pt" class="chamois_back" width="100%">
# <tr><td>
# <br/>
# <span class="latin16">Sentence: </span>
# <span class="deva16" lang="sa">क्षेत्रगामिना वर्त्मना आगच्छति यात्रिकम् अपश्यत्</span><br/><div class="latin16"><table class="spacing20">
# <tr>
# <td><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=">✓</a>Undo</td><td>(300 Solutions)</td></tr>
# </table>
# </div><br/>
# <div class="latin12"><table class="center">
# <tr><td>k</td><td>ṣ</td><td>e</td><td>t</td><td>r</td><td>a</td><td>g</td><td>ā</td><td>m</td><td>i</td><td>n</td><td>ā</td><td>_</td><td>v</td><td>a</td><td>r</td><td>t</td><td>m</td><td>a</td><td>n</td><td>ā</td><td>_</td><td>ā</td><td>g</td><td>a</td><td>c</td><td>ch</td><td>a</td><td>t</td><td>i</td><td> </td><td>y</td><td>ā</td><td>t</td><td>r</td><td>i</td><td>k</td><td>a</td><td>m</td><td> </td><td>a</td><td>p</td><td>a</td><td>ś</td><td>y</td><td>a</td><td>t</td><td> </td></tr>
# <tr><td align="left" colspan="6"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/23.html#k.setra&quot;&gt;&lt;i&gt;kṣetra&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">kṣetra</td></tr></table><span class="blue">✓</span></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ i. sg. m. | i. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gaamin&quot;&gt;&lt;i&gt;gāmin&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">gāminā</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaaminaa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaaminaa},{f}">✘</a></td><td></td><td align="left" colspan="6"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/57.html#vartman&quot;&gt;&lt;i&gt;vartman&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">vartma</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Iicc},{vartma},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Iicc},{vartma},{f}">✘</a></td><td align="left" colspan="2"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/37.html#nau#1&quot;&gt;&lt;i&gt;nau_1&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">nau</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Iicc},{nau},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Iicc},{nau},{f}">✘</a></td><td></td><td align="left" colspan="8"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ loc. sg. n. | loc. sg. m. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/9.html#aa&quot;&gt;&lt;i&gt;ā&lt;/i&gt;&lt;/a&gt;-&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gacchat&quot;&gt;&lt;i&gt;gacchat&lt;/i&gt;&lt;/a&gt; { ppr. [1] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/9.html#aa&quot;&gt;&lt;i&gt;ā&lt;/i&gt;&lt;/a&gt;-&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gam&quot;&gt;&lt;i&gt;gam&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">āgacchati</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pvkv}{Kric}{aa}{gacchati}&gt;,{aagacchati},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pvkv}{Kric}{aa}{gacchati}&gt;,{aagacchati},{f}">✘</a></td><td></td><td align="left" colspan="8"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. m. | acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/53.html#yaatrika&quot;&gt;&lt;i&gt;yātrika&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">yātrikam</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Nouc},{yaatrikam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Nouc},{yaatrikam},{f}">✘</a></td><td></td><td align="left" colspan="7"><table class="carmin_back">
# <tr><td onclick="showBox('{ impft. [4] ac. sg. 3 }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#paz&quot;&gt;&lt;i&gt;paś&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FF1975', this, event)">apaśyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Root},{apazyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Root},{apazyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="3"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. m. | acc. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/25.html#go&quot;&gt;&lt;i&gt;go&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">gām</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaam},{f}">✘</a></td><td align="left" colspan="4"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ nom. pl. m. | acc. pl. f. | nom. pl. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/11.html#ina&quot;&gt;&lt;i&gt;ina&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">ināḥ</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaas},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaas},{f}">✘</a></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/57.html#vartman&quot;&gt;&lt;i&gt;vartman&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">vartma</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Nouc},{vartma},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Nouc},{vartma},{f}">✘</a></td><td align="left" colspan="2"><table class="light_blue_back">
# <tr><td onclick="showBox('{ g. du. * | dat. du. * | acc. du. * }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/8.html#asmad&quot;&gt;&lt;i&gt;asmad&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#ADD8E6', this, event)">nau</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Pron},{nau},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Pron},{nau},{f}">✘</a></td><td></td><td align="left" colspan="8"><table class="carmin_back">
# <tr><td onclick="showBox('{ pr. [1] ac. sg. 3 }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/9.html#aa&quot;&gt;&lt;i&gt;ā&lt;/i&gt;&lt;/a&gt;-&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gam&quot;&gt;&lt;i&gt;gam&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FF1975', this, event)">āgacchati</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pv}{Root}{aa}{gacchati}&gt;,{aagacchati},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pv}{Root}{aa}{gacchati}&gt;,{aagacchati},{f}">✘</a></td><td></td><td align="left" colspan="2"><table class="light_blue_back">
# <tr><td onclick="showBox('{ nom. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/53.html#yad&quot;&gt;&lt;i&gt;yad&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#ADD8E6', this, event)">yā</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Pron},{yaa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Pron},{yaa},{f}">✘</a></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. m. | acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/30.html#trika&quot;&gt;&lt;i&gt;trika&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">trikam</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=33,{Nouc},{trikam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=33,{Nouc},{trikam},{f}">✘</a></td><td></td><td align="left" colspan="3"><table class="mauve_back">
# <tr><td onclick="showBox('{ prep. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/4.html#apa&quot;&gt;&lt;i&gt;apa&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FF99FF', this, event)">apa</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Inde},{apa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Inde},{apa},{f}">✘</a></td><td align="left" colspan="4"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. n. | nom. sg. n. }[śyat { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/63.html#zaa&quot;&gt;&lt;i&gt;śā&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">śyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Kric},{zyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Kric},{zyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="3"><table class="cyan_back">
# <tr><td onclick="showBox('{ acc. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#ga#1&quot;&gt;&lt;i&gt;ga_1&lt;/i&gt;&lt;/a&gt;]&lt;br&gt;{ acc. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#ga#2&quot;&gt;&lt;i&gt;ga_2&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00FFFF', this, event)">gām</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Ifc},{gaam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Ifc},{gaam},{f}">✘</a></td><td align="left" colspan="3"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ nom. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/11.html#ina&quot;&gt;&lt;i&gt;ina&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">inā</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaa},{f}">✘</a></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="1"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/1.html#a&quot;&gt;&lt;i&gt;a&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">a</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=32,{A},{a},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=32,{A},{a},{f}">✘</a></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="1"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/1.html#a&quot;&gt;&lt;i&gt;a&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">a</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{A},{a},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{A},{a},{f}">✘</a></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#pazyat&quot;&gt;&lt;i&gt;paśyat&lt;/i&gt;&lt;/a&gt; { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#paz&quot;&gt;&lt;i&gt;paś&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">paśyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Kric},{pazyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Kric},{pazyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="6"><table class="lawngreen_back">
# <tr><td onclick="showBox('{ voc. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#pazyat&quot;&gt;&lt;i&gt;paśyat&lt;/i&gt;&lt;/a&gt; { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#paz&quot;&gt;&lt;i&gt;paś&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#7CFC00', this, event)">paśyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Vokc},{pazyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Vokc},{pazyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="4"><table class="lawngreen_back">
# <tr><td onclick="showBox('{ voc. sg. n. }[śyat { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/63.html#zaa&quot;&gt;&lt;i&gt;śā&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#7CFC00', this, event)">śyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Vokc},{zyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Vokc},{zyat},{f}">✘</a></td><td></td></tr>
# </table>
# </div><br/>
# <br/>
# <br/>
# </td></tr></table>

# %%
tablebody = table.find('table',{'class' : 'center'})
print(tablebody)
# Out:
# <table class="center">
# <tr><td>k</td><td>ṣ</td><td>e</td><td>t</td><td>r</td><td>a</td><td>g</td><td>ā</td><td>m</td><td>i</td><td>n</td><td>ā</td><td>_</td><td>v</td><td>a</td><td>r</td><td>t</td><td>m</td><td>a</td><td>n</td><td>ā</td><td>_</td><td>ā</td><td>g</td><td>a</td><td>c</td><td>ch</td><td>a</td><td>t</td><td>i</td><td> </td><td>y</td><td>ā</td><td>t</td><td>r</td><td>i</td><td>k</td><td>a</td><td>m</td><td> </td><td>a</td><td>p</td><td>a</td><td>ś</td><td>y</td><td>a</td><td>t</td><td> </td></tr>
# <tr><td align="left" colspan="6"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/23.html#k.setra&quot;&gt;&lt;i&gt;kṣetra&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">kṣetra</td></tr></table><span class="blue">✓</span></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ i. sg. m. | i. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gaamin&quot;&gt;&lt;i&gt;gāmin&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">gāminā</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaaminaa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaaminaa},{f}">✘</a></td><td></td><td align="left" colspan="6"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/57.html#vartman&quot;&gt;&lt;i&gt;vartman&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">vartma</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Iicc},{vartma},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Iicc},{vartma},{f}">✘</a></td><td align="left" colspan="2"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/37.html#nau#1&quot;&gt;&lt;i&gt;nau_1&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">nau</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Iicc},{nau},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Iicc},{nau},{f}">✘</a></td><td></td><td align="left" colspan="8"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ loc. sg. n. | loc. sg. m. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/9.html#aa&quot;&gt;&lt;i&gt;ā&lt;/i&gt;&lt;/a&gt;-&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gacchat&quot;&gt;&lt;i&gt;gacchat&lt;/i&gt;&lt;/a&gt; { ppr. [1] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/9.html#aa&quot;&gt;&lt;i&gt;ā&lt;/i&gt;&lt;/a&gt;-&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gam&quot;&gt;&lt;i&gt;gam&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">āgacchati</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pvkv}{Kric}{aa}{gacchati}&gt;,{aagacchati},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pvkv}{Kric}{aa}{gacchati}&gt;,{aagacchati},{f}">✘</a></td><td></td><td align="left" colspan="8"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. m. | acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/53.html#yaatrika&quot;&gt;&lt;i&gt;yātrika&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">yātrikam</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Nouc},{yaatrikam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Nouc},{yaatrikam},{f}">✘</a></td><td></td><td align="left" colspan="7"><table class="carmin_back">
# <tr><td onclick="showBox('{ impft. [4] ac. sg. 3 }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#paz&quot;&gt;&lt;i&gt;paś&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FF1975', this, event)">apaśyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Root},{apazyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Root},{apazyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="3"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. m. | acc. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/25.html#go&quot;&gt;&lt;i&gt;go&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">gām</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Nouc},{gaam},{f}">✘</a></td><td align="left" colspan="4"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ nom. pl. m. | acc. pl. f. | nom. pl. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/11.html#ina&quot;&gt;&lt;i&gt;ina&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">ināḥ</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaas},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaas},{f}">✘</a></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/57.html#vartman&quot;&gt;&lt;i&gt;vartman&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">vartma</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Nouc},{vartma},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=13,{Nouc},{vartma},{f}">✘</a></td><td align="left" colspan="2"><table class="light_blue_back">
# <tr><td onclick="showBox('{ g. du. * | dat. du. * | acc. du. * }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/8.html#asmad&quot;&gt;&lt;i&gt;asmad&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#ADD8E6', this, event)">nau</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Pron},{nau},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=19,{Pron},{nau},{f}">✘</a></td><td></td><td align="left" colspan="8"><table class="carmin_back">
# <tr><td onclick="showBox('{ pr. [1] ac. sg. 3 }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/9.html#aa&quot;&gt;&lt;i&gt;ā&lt;/i&gt;&lt;/a&gt;-&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#gam&quot;&gt;&lt;i&gt;gam&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FF1975', this, event)">āgacchati</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pv}{Root}{aa}{gacchati}&gt;,{aagacchati},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=22,&lt;{Pv}{Root}{aa}{gacchati}&gt;,{aagacchati},{f}">✘</a></td><td></td><td align="left" colspan="2"><table class="light_blue_back">
# <tr><td onclick="showBox('{ nom. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/53.html#yad&quot;&gt;&lt;i&gt;yad&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#ADD8E6', this, event)">yā</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Pron},{yaa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=31,{Pron},{yaa},{f}">✘</a></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. m. | acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/30.html#trika&quot;&gt;&lt;i&gt;trika&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">trikam</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=33,{Nouc},{trikam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=33,{Nouc},{trikam},{f}">✘</a></td><td></td><td align="left" colspan="3"><table class="mauve_back">
# <tr><td onclick="showBox('{ prep. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/4.html#apa&quot;&gt;&lt;i&gt;apa&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FF99FF', this, event)">apa</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Inde},{apa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{Inde},{apa},{f}">✘</a></td><td align="left" colspan="4"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. n. | nom. sg. n. }[śyat { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/63.html#zaa&quot;&gt;&lt;i&gt;śā&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">śyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Kric},{zyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Kric},{zyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="3"><table class="cyan_back">
# <tr><td onclick="showBox('{ acc. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#ga#1&quot;&gt;&lt;i&gt;ga_1&lt;/i&gt;&lt;/a&gt;]&lt;br&gt;{ acc. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/24.html#ga#2&quot;&gt;&lt;i&gt;ga_2&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00FFFF', this, event)">gām</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Ifc},{gaam},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=6,{Ifc},{gaam},{f}">✘</a></td><td align="left" colspan="3"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ nom. sg. f. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/11.html#ina&quot;&gt;&lt;i&gt;ina&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">inā</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaa},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=9,{Nouv},{inaa},{f}">✘</a></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="1"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/1.html#a&quot;&gt;&lt;i&gt;a&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">a</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=32,{A},{a},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=32,{A},{a},{f}">✘</a></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="1"><table class="yellow_back">
# <tr><td onclick="showBox('{ iic. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/1.html#a&quot;&gt;&lt;i&gt;a&lt;/i&gt;&lt;/a&gt;]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#FFFF00', this, event)">a</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{A},{a},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=40,{A},{a},{f}">✘</a></td><td align="left" colspan="6"><table class="deep_sky_back">
# <tr><td onclick="showBox('{ acc. sg. n. | nom. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#pazyat&quot;&gt;&lt;i&gt;paśyat&lt;/i&gt;&lt;/a&gt; { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#paz&quot;&gt;&lt;i&gt;paś&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#00C0FF', this, event)">paśyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Kric},{pazyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Kric},{pazyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="6"><table class="lawngreen_back">
# <tr><td onclick="showBox('{ voc. sg. n. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#pazyat&quot;&gt;&lt;i&gt;paśyat&lt;/i&gt;&lt;/a&gt; { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/39.html#paz&quot;&gt;&lt;i&gt;paś&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#7CFC00', this, event)">paśyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Vokc},{pazyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=41,{Vokc},{pazyat},{f}">✘</a></td><td></td></tr>
# <tr><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td></td><td align="left" colspan="4"><table class="lawngreen_back">
# <tr><td onclick="showBox('{ voc. sg. n. }[śyat { ppr. [4] ac. }[&lt;a href=&quot;http://sanskrit.inria.fr/DICO/63.html#zaa&quot;&gt;&lt;i&gt;śā&lt;/i&gt;&lt;/a&gt;]]&lt;a href=&quot;javascript:hideBox()&quot;&gt; ✘&lt;/a&gt;', '#7CFC00', this, event)">śyat</td></tr></table><a class="green" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Vokc},{zyat},{t}">✓</a><a class="red" href="/cgi-bin/SKT/sktgraph?t=WX;lex=SH;cache=f;st=t;us=f;cp=t;text=kRewragAminA+varwmanA+AgacCawi+yAwrikaM+apaSyaw;topic=;abs=f;corpmode=;corpdir=;sentno=;allSol=300;cpts=43,{Vokc},{zyat},{f}">✘</a></td><td></td></tr>
# </table>

# %%
t = pd.DataFrame(columns = ['id','level','color_class','position','chunk_no','word','lemma','pre_verb','morph','colspan','wordlenth','aux_inf'])
t
# Out:
# Empty DataFrame
# Columns: [id, level, color_class, position, chunk_no, word, lemma, pre_verb, morph, colspan, wordlenth, aux_inf]
# Index: []

# %%
# print(tablebody.children
#      )
# print("\n\n\n")
for child in tablebody.children:
    if(child.name == 'tr') :
        print(child.name)
# Out:
# tr
# tr
# tr
# tr
# tr
# tr

# %%
'id','level','color_class','position','chunk_no','word','lemma','morph','colspan','wordlenth','pre_verb','aux_inf'
# Out:
# ('id',
#  'level',
#  'color_class',
#  'position',
#  'chunk_no',
#  'word',
#  'lemma',
#  'morph',
#  'colspan',
#  'wordlenth',
#  'pre_verb',
#  'aux_inf')

# %%
i = 0
id_= 0
for child in tablebody.children:
    if(child.name == 'tr') :
        if i< 1 : 
            linechar = []
            c=0
            for char in child.children :
                linechar.append(char.string)
                c += 1
            i+=1
            line = "".join(linechar)
            linechunks = line.split("\xa0")
            continue
        position_ = 0
        j =0
        for wordtable in child.children:
#             if(j < 20 ) :
#                 j += 1
#                 continue
            c= 0
            for ch in linechar[0:position_] :
                if(re.match('\xa0',ch)) : 
                    c+=1
            if(wordtable.contents):
                color_ = wordtable.table.get('class')[0]
                colspan_= wordtable.get('colspan')
                word_ = wordtable.table.tr.td.string
                onclickdatas_ = wordtable.table.tr.td.get('onclick')
                for onclickdata_ in onclickdatas_.split("<br>") :
                    morphslist_ = re.findall(r'{ (.*?) }',onclickdata_)  #.split(' | ')
                    ldata = str(re.search(r'{.*?}\[(.*)\]',onclickdata_).group(1))
                    ldata = str(re.sub(r'</?a.*?>|</?i>',"",ldata))

                    lemmadata = ldata.split(" ")
                    if len(lemmadata) >1 :
                        auxi_ = " ".join(lemmadata[1:])
                    else :
                        auxi_ = ""
                    lemmas_ = "".join(lemmadata[0])
                    lemmalists_ = lemmas_.split("-")
                    if(len(lemmalists_) > 1) :
                        preverb_ = ",".join(lemmalists_[0:(len(lemmalists_)-1)])
                        lemmalist_ = "".join(lemmalists_[-1:]).split("_")
                    else :
                        preverb_ = ""
                        lemmalist_ = "".join(lemmalists_[0]).split("_")
                    if(len(lemmalist_) > 1):
                        auxi_ =auxi_ + " sence of lemma = " + "".join(lemmalist_[1:(len(lemmalist_))])
                        lemma_ = "".join(lemmalist_[0])
                    else : 
                        lemma_ = "".join(lemmalist_[0])             
                    morphs_ = str(morphslist_[0])               
                    for morph_ in morphs_.split(" | ") : 
                        t.loc[id_] = [id_,i,color_,position_,c+1,word_,lemma_,preverb_,morph_,colspan_,len(word_),auxi_]
                        id_ += 1    


                position_ += int(colspan_)
    #                 break
            else : 
                position_ += 1

#         break
        
        i = i+1

        
# print(color_)
# print(colspan_)
# print(position_)
# print(word_)
# print(onclickdata_)
# print(ldata)
# print(morphslist_)
# print(lemmalists_)
# print(auxi_)
# print(lemma_)
# print(morphs_)
# print(preverb_)
# print(linechar) 
print(line)
# c= 0
# for ch in linechar[0:position_] :
#     if(re.match('\xa0',ch)) : 
#         c+=1
# print(c)
t
# Out:
# kṣetragāminā_vartmanā_āgacchati yātrikam apaśyat
#     id level      color_class position chunk_no       word    lemma pre_verb  \
# 0    0     1      yellow_back        0        1     kṣetra   kṣetra
# 1    1     1    deep_sky_back        6        1     gāminā    gāmin
# 2    2     1    deep_sky_back        6        1     gāminā    gāmin
# 3    3     1      yellow_back       13        1     vartma  vartman
# 4    4     1      yellow_back       19        1        nau      nau
# 5    5     1    deep_sky_back       22        1  āgacchati  gacchat        ā
# 6    6     1    deep_sky_back       22        1  āgacchati  gacchat        ā
# 7    7     1    deep_sky_back       31        2   yātrikam  yātrika
# 8    8     1    deep_sky_back       31        2   yātrikam  yātrika
# 9    9     1    deep_sky_back       31        2   yātrikam  yātrika
# 10  10     1      carmin_back       40        3    apaśyat      paś
# 11  11     2    deep_sky_back        6        1        gām       go
# 12  12     2    deep_sky_back        6        1        gām       go
# 13  13     2    deep_sky_back        9        1       ināḥ      ina
# 14  14     2    deep_sky_back        9        1       ināḥ      ina
# 15  15     2    deep_sky_back        9        1       ināḥ      ina
# 16  16     2    deep_sky_back       13        1     vartma  vartman
# 17  17     2    deep_sky_back       13        1     vartma  vartman
# 18  18     2  light_blue_back       19        1        nau    asmad
# 19  19     2  light_blue_back       19        1        nau    asmad
# 20  20     2  light_blue_back       19        1        nau    asmad
# 21  21     2      carmin_back       22        1  āgacchati      gam        ā
# 22  22     2  light_blue_back       31        2         yā      yad
# 23  23     2    deep_sky_back       33        2     trikam    trika
# 24  24     2    deep_sky_back       33        2     trikam    trika
# 25  25     2    deep_sky_back       33        2     trikam    trika
# 26  26     2       mauve_back       40        3        apa      apa
# 27  27     2    deep_sky_back       43        3       śyat     śyat
# 28  28     2    deep_sky_back       43        3       śyat     śyat
# 29  29     3        cyan_back        6        1        gām       ga
# 30  30     3        cyan_back        6        1        gām       ga
# 31  31     3    deep_sky_back        9        1        inā      ina
# 32  32     3      yellow_back       32        2          a        a
# 33  33     3      yellow_back       40        3          a        a
# 34  34     3    deep_sky_back       41        3     paśyat   paśyat
# 35  35     3    deep_sky_back       41        3     paśyat   paśyat
# 36  36     4   lawngreen_back       41        3     paśyat   paśyat
# 37  37     5   lawngreen_back       43        3       śyat     śyat
#
#                    morph colspan wordlenth                  aux_inf
# 0                   iic.       6         6
# 1              i. sg. m.       6         6
# 2              i. sg. n.       6         6
# 3                   iic.       6         6
# 4                   iic.       2         3       sence of lemma = 1
# 5            loc. sg. n.       8         9  { ppr. [1] ac. }[ā-gam]
# 6            loc. sg. m.       8         9  { ppr. [1] ac. }[ā-gam]
# 7            acc. sg. m.       8         8
# 8            acc. sg. n.       8         8
# 9            nom. sg. n.       8         8
# 10  impft. [4] ac. sg. 3       7         7
# 11           acc. sg. m.       3         3
# 12           acc. sg. f.       3         3
# 13           nom. pl. m.       4         4
# 14           acc. pl. f.       4         4
# 15           nom. pl. f.       4         4
# 16           acc. sg. n.       6         6
# 17           nom. sg. n.       6         6
# 18              g. du. *       2         3
# 19            dat. du. *       2         3
# 20            acc. du. *       2         3
# 21     pr. [1] ac. sg. 3       8         9
# 22           nom. sg. f.       2         2
# 23           acc. sg. m.       6         6
# 24           acc. sg. n.       6         6
# 25           nom. sg. n.       6         6
# 26                 prep.       3         3
# 27           acc. sg. n.       4         4     { ppr. [4] ac. }[śā]
# 28           nom. sg. n.       4         4     { ppr. [4] ac. }[śā]
# 29           acc. sg. f.       3         3       sence of lemma = 1
# 30           acc. sg. f.       3         3       sence of lemma = 2
# 31           nom. sg. f.       3         3
# 32                  iic.       1         1
# 33                  iic.       1         1
# 34           acc. sg. n.       6         6    { ppr. [4] ac. }[paś]
# 35           nom. sg. n.       6         6    { ppr. [4] ac. }[paś]
# 36           voc. sg. n.       6         6    { ppr. [4] ac. }[paś]
# 37           voc. sg. n.       4         4     { ppr. [4] ac. }[śā]
